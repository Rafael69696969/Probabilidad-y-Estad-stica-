# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafael69696969/Probabilidad-y-Estad-stica-/blob/main/Unidad1/Practica4y5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# Unidad 1
#
# ##Practica 4. Tablas de Frecuencias
#
# ###Facilitador: Dr. José Gabriel Rodríguez Rivas
#
# ###Alumno:Rafael Alejandro Arenas Ferrel

# %%
import random
edades = []
for i in range(100):
  numero_aleatorio = random.randint(18, 70)
  edades.append(numero_aleatorio)
print(edades)
import pandas as pd
df = pd.DataFrame(edades,columns=['Edad'])
df.head()
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values (by='Edad')
tabla_frecuencias
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] /100
tabla_frecuencias
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] /100 * 100
tabla_frecuencias
tabla_frecuencias['Frec acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
import math
print(edades)
df = pd.DataFrame({'Edad': edades})
df
n = len(edades)
K = int(1+ math.log2(n))
print("Valor de n =", n, "\nNúmero de intervalos =", K)
tabla_frecuencia = pd.cut(df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()
print(tabla_frecuencia)
import matplotlib.pyplot as plt #impor
plt.hist(edades, alpha = 0.5)
plt.title("Historama de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# [47, 53, 51, 54, 21, 49, 28, 53, 41, 20, 45, 32, 58, 56, 54, 35, 23, 24, 52, 65, 34, 38, 63, 53, 54, 19, 58, 60, 60, 58, 59, 36, 60, 23, 48, 32, 45, 35, 67, 37, 60, 58, 39, 68, 67, 25, 18, 22, 27, 28, 21, 53, 28, 37, 66, 35, 27, 45, 44, 67, 18, 46, 39, 39, 64, 57, 59, 58, 29, 40, 33, 33, 46, 58, 31, 64, 52, 62, 25, 19, 48, 21, 70, 65, 58, 37, 51, 46, 33, 54, 46, 66, 20, 38, 66, 55, 46, 32, 41, 45]
# [47, 53, 51, 54, 21, 49, 28, 53, 41, 20, 45, 32, 58, 56, 54, 35, 23, 24, 52, 65, 34, 38, 63, 53, 54, 19, 58, 60, 60, 58, 59, 36, 60, 23, 48, 32, 45, 35, 67, 37, 60, 58, 39, 68, 67, 25, 18, 22, 27, 28, 21, 53, 28, 37, 66, 35, 27, 45, 44, 67, 18, 46, 39, 39, 64, 57, 59, 58, 29, 40, 33, 33, 46, 58, 31, 64, 52, 62, 25, 19, 48, 21, 70, 65, 58, 37, 51, 46, 33, 54, 46, 66, 20, 38, 66, 55, 46, 32, 41, 45]
# Valor de n = 100
# Número de intervalos = 7
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 3  (17.947, 25.429]    15      0.15       15.0       15         0.15
# 6  (25.429, 32.857]    10      0.10       10.0       25         0.25
# 0  (32.857, 40.286]    17      0.17       17.0       42         0.42
# 4  (40.286, 47.714]    13      0.13       13.0       55         0.55
# 1  (47.714, 55.143]    16      0.16       16.0       71         0.71
# 2  (55.143, 62.571]    16      0.16       16.0       87         0.87
# 5    (62.571, 70.0]    13      0.13       13.0      100         1.00
#
#    Frec Porc Ac
# 3          15.0
# 6          25.0
# 0          42.0
# 4          55.0
# 1          71.0
# 2          87.0
# 5         100.0
# Text(0.5, 1.0, 'Historama de edades basado en la funcion de matplotlib con valores estandar')

# %% [markdown]
# Practica 5: Diagrama de Cajas y Bigotes

# %%
edades2 = []

for i in range (100):
  numero_aleatorio = random.randint( 20, 87)
  edades2.append(numero_aleatorio)
print(edades2)
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('Edades Encuesta 2')
plt.show()
edades2.append(130)
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('Edades Encuesta 2')
plt.show()
# Out:
# [61, 26, 70, 38, 76, 79, 68, 42, 36, 20, 59, 60, 76, 74, 57, 80, 49, 52, 84, 66, 82, 82, 31, 47, 46, 36, 63, 69, 42, 80, 45, 32, 63, 81, 22, 53, 76, 52, 34, 83, 87, 86, 68, 37, 29, 82, 68, 80, 39, 43, 47, 20, 28, 54, 34, 36, 75, 81, 22, 68, 46, 81, 45, 55, 71, 58, 74, 20, 43, 41, 86, 45, 70, 46, 78, 43, 45, 42, 67, 52, 58, 52, 33, 37, 74, 43, 22, 49, 71, 20, 42, 33, 82, 35, 63, 70, 70, 37, 56, 75]
